# %% [markdown]
# # Dense networks on CIFAR10
#
# In this lab you will see how well neural networks with fully connected layers perform on a dataset with more complex images. For example, CIFAR10 images have RGB values and thus each pixel corresponds to three values.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data

import time

# %%
# Choose which device to use
use_cuda = False

if use_cuda and torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

device
# Out:
# device(type='cpu')

# %% [markdown]
# ### Load the dataset

# %%
import torchvision
import torchvision.transforms as transforms

# Apply transformations to the data points before passing them to the network
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])  # The data is normalized by subtracting the mean and dividing by the std (corresponding to each channel)

trainset = torchvision.datasets.CIFAR10(root='./data_cifar', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data_cifar', train=False,
                                       download=True, transform=transform)

batch_size = 128
w, h, c = 32, 32, 3  # Width, Height, Nr. of channels for the input images (RGB)
k = 10  # Number of output classes

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=batch_size,
                                          shuffle=True)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=batch_size,
                                         shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Show image examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
#images, labels = dataiter.next()
images, labels = next(dataiter)


print(images[0].shape)
print(images.shape)

# show images
imshow(images[0])
imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.3146615..1.4100931].
# torch.Size([3, 32, 32])
# torch.Size([128, 3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49473685..1.5654321].

# %% [markdown]
# ### Exercise - Defining an architecture
#
# In this lab we will use fully connected neural networks. Create a dense neural network class that has a variable number of layers and layer sizes. The hidden layers have ReLu activation. The output layer should not apply any activation function.

# %%
class MLP(nn.Module):

  def __init__(self,
               input_size,  # Size of the input. Here we will first flatten the image to a single vector with the 3 * 32 * 32 values in the image 
               layer_sizes,  # A tuple containing the sizes of the hidden layers of the neural network. So to create a NN with two hidden layers with 32 neurons in each layer you'd set layer_sizes=(32,32)
               output_size):  # The size of the network output. CIFAR10 has 10 output classes
    super(MLP, self).__init__()
    shape = (input_size,) + layer_sizes + (output_size,)
    self.layers = nn.ModuleList([nn.Linear(shape[i], shape[i+1]) for i in range(len(shape) - 1)])

    #pass  # COMPLETE THE CODE HERE

  def forward(self, x):
    for layer in self.layers[:-1]:
      x = F.relu(layer(x))
    return self.layers[-1](x)
    #pass  # COMPLETE THE CODE HERE

# %%
model = MLP(w * h * c, (128, 128), k).to(device)  # Create a new dense neural network with two hidden layers of size 128

print(model)
# Out:
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3072, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Train the network
#
# Finish the code below so the network is trained on the images. The network should be able to reach an accuracy of about 50%. This is much better than taking random guesses, so the network did learn something. However, it is not a great classifier either. Dense neural networks are usually not the way to go for image classification. Instead, Convolutional Neural Networks are often used. These will be covered in the next lecture.

# %%
start=time.time()

criterion = nn.CrossEntropyLoss()

lr = 0.01 # COMPLETE THE CODE HERE
momentum = 0.5 # COMPLETE THE CODE HERE
num_epochs = 20 # COMPLETE THE CODE HERE

optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

for epoch in range(1, num_epochs + 1):
  # Iterate through the entire train set
  for i, (x_batch, y_batch) in enumerate(trainloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used
    

    # Perform an optimization step on the network weights using the gradient of the loss function

    # COMPLETE THE CODE HERE
    optimizer.zero_grad()  # Set all currently stored gradients to zero 

    #x_batch = x_batch.view(-1, w*h*c)  # Reshape the input tensor
    #y_pred = model(x_batch)  # Perform the forward pass


    y_pred = model(x_batch.view(-1, w*h*c)) # COMPLETE THE CODE HERE

    loss = criterion(y_pred, y_batch) # COMPLETE THE CODE HERE

    # COMPLETE THE CODE HERE
    loss.backward()
    optimizer.step()

    # Compute relevant metrics
        
    y_pred_max = torch.argmax(y_pred, dim=1)  # Get the labels with highest output probability

    correct = torch.sum(torch.eq(y_pred_max, y_batch)).item()  # Count how many are equal to the true labels

    elapsed = time.time() - start  # Keep track of how much time has elapsed

    # Show progress every 20 batches 
    if not i % 20:
      print(f'epoch: {epoch}, time: {elapsed:.3f}s, loss: {loss.item():.3f}, train accuracy: {correct / batch_size:.3f}')
    
  # Evaluate the model on the test set
  correct_total = 0
  for i, (x_batch, y_batch) in enumerate(testloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used

    y_pred = model(x_batch.view(-1, w * h * c))
    y_pred_max = torch.argmax(y_pred, dim=1)

    correct_total += torch.sum(torch.eq(y_pred_max, y_batch)).item()

  print(f'Test accuracy: {correct_total / len(testset.data):.3f}')
# Out:
# epoch: 1, time: 0.127s, loss: 2.302, train accuracy: 0.086
# epoch: 1, time: 0.552s, loss: 2.241, train accuracy: 0.164
# epoch: 1, time: 0.945s, loss: 2.183, train accuracy: 0.281
# epoch: 1, time: 1.343s, loss: 2.132, train accuracy: 0.273
# epoch: 1, time: 1.774s, loss: 2.040, train accuracy: 0.242
# epoch: 1, time: 2.211s, loss: 1.990, train accuracy: 0.328
# epoch: 1, time: 2.607s, loss: 1.842, train accuracy: 0.352
# epoch: 1, time: 2.987s, loss: 1.893, train accuracy: 0.344
# epoch: 1, time: 3.365s, loss: 1.905, train accuracy: 0.367
# epoch: 1, time: 3.757s, loss: 1.950, train accuracy: 0.242
# epoch: 1, time: 4.149s, loss: 1.819, train accuracy: 0.352
# epoch: 1, time: 4.571s, loss: 1.817, train accuracy: 0.375
# epoch: 1, time: 4.967s, loss: 1.769, train accuracy: 0.367
# epoch: 1, time: 5.364s, loss: 1.664, train accuracy: 0.430
# epoch: 1, time: 5.739s, loss: 1.890, train accuracy: 0.359
# epoch: 1, time: 6.112s, loss: 1.769, train accuracy: 0.398
# epoch: 1, time: 6.488s, loss: 1.695, train accuracy: 0.438
# epoch: 1, time: 6.867s, loss: 1.816, train accuracy: 0.398
# epoch: 1, time: 7.241s, loss: 1.767, train accuracy: 0.305
# epoch: 1, time: 7.613s, loss: 1.617, train accuracy: 0.398
# Test accuracy: 0.404
# epoch: 2, time: 9.100s, loss: 1.755, train accuracy: 0.367
# epoch: 2, time: 9.470s, loss: 1.806, train accuracy: 0.312
# epoch: 2, time: 9.846s, loss: 1.646, train accuracy: 0.430
# epoch: 19, time: 159.809s, loss: 0.886, train accuracy: 0.695
# epoch: 19, time: 160.184s, loss: 0.819, train accuracy: 0.703
# epoch: 19, time: 160.574s, loss: 1.092, train accuracy: 0.625
# epoch: 19, time: 160.948s, loss: 1.057, train accuracy: 0.625
# epoch: 19, time: 161.325s, loss: 0.994, train accuracy: 0.680
# epoch: 19, time: 161.725s, loss: 1.037, train accuracy: 0.594
# epoch: 19, time: 162.112s, loss: 0.986, train accuracy: 0.633
# epoch: 19, time: 162.488s, loss: 0.942, train accuracy: 0.672
# epoch: 19, time: 162.868s, loss: 1.002, train accuracy: 0.633
# epoch: 19, time: 163.262s, loss: 0.953, train accuracy: 0.594
# epoch: 19, time: 163.657s, loss: 1.022, train accuracy: 0.656
# epoch: 19, time: 164.035s, loss: 1.139, train accuracy: 0.664
# Test accuracy: 0.527
# epoch: 20, time: 165.594s, loss: 0.911, train accuracy: 0.672
# epoch: 20, time: 165.971s, loss: 0.925, train accuracy: 0.719
# epoch: 20, time: 166.355s, loss: 0.963, train accuracy: 0.617
# epoch: 20, time: 166.741s, loss: 1.097, train accuracy: 0.586
# epoch: 20, time: 167.123s, loss: 0.783, train accuracy: 0.750
# epoch: 20, time: 167.501s, loss: 0.955, train accuracy: 0.688
# epoch: 20, time: 167.876s, loss: 0.954, train accuracy: 0.688
# epoch: 20, time: 168.267s, loss: 1.032, train accuracy: 0.594
# epoch: 20, time: 168.660s, loss: 0.928, train accuracy: 0.688
# epoch: 20, time: 169.046s, loss: 0.948, train accuracy: 0.625
# epoch: 20, time: 169.455s, loss: 1.195, train accuracy: 0.602
# epoch: 20, time: 169.842s, loss: 1.021, train accuracy: 0.656
# epoch: 20, time: 170.226s, loss: 1.122, train accuracy: 0.609
# epoch: 20, time: 170.612s, loss: 0.781, train accuracy: 0.719
# epoch: 20, time: 170.991s, loss: 0.952, train accuracy: 0.625
# epoch: 20, time: 171.363s, loss: 1.112, train accuracy: 0.641
# epoch: 20, time: 171.738s, loss: 0.836, train accuracy: 0.719
# epoch: 20, time: 172.107s, loss: 1.009, train accuracy: 0.641
# epoch: 20, time: 172.477s, loss: 1.153, train accuracy: 0.547
# epoch: 20, time: 172.844s, loss: 1.023, train accuracy: 0.586
# Test accuracy: 0.524

# %%
import os

folder_path = 'Densenet_on_cifarData/'

if not os.path.isdir(folder_path):
  os.mkdir(folder_path)
  print('Folder created!')

# %%
torch.save(model, folder_path + 'model.pth')

# %%
model = torch.load(folder_path + 'model.pth')
print(model)
# Out:
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3072, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
torch.save(model.state_dict(), folder_path + 'model_state.pth')

# %%
model_state = torch.load(folder_path + 'model_state.pth')  # Load the model's weights
model = MLP(w * h * c, (128, 128), k).to(device)  # Create a new dense neural network with two hidden layers of size 128
model.load_state_dict(model_state)  # Set the model weights to the saved weights. Note that the model architecture must be equal to the architecture of the model from which the state_dict was obtained!
# Out:
# <All keys matched successfully>
