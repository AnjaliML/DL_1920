# %% [markdown]
# # Dense networks on CIFAR10
#
# In this lab you will see how well neural networks with fully connected layers perform on a dataset with more complex images. For example, CIFAR10 images have RGB values and thus each pixel corresponds to three values.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data

import time

# %%
# Choose which device to use
use_cuda = False

if use_cuda and torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

device
# Out:
# device(type='cpu')

# %% [markdown]
# ### Load the dataset

# %%
import torchvision
import torchvision.transforms as transforms

# Apply transformations to the data points before passing them to the network
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])  # The data is normalized by subtracting the mean and dividing by the std (corresponding to each channel)

trainset = torchvision.datasets.CIFAR10(root='./data_cifar', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data_cifar', train=False,
                                       download=True, transform=transform)

batch_size = 128
w, h, c = 32, 32, 3  # Width, Height, Nr. of channels for the input images (RGB)
k = 10  # Number of output classes

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=batch_size,
                                          shuffle=True)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=batch_size,
                                         shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Show image examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

print(images[0].shape)
print(images.shape)

# show images
imshow(images[0])
imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# torch.Size([128, 3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Exercise - Defining an architecture
#
# In this lab we will use fully connected neural networks. Create a dense neural network class that has a variable number of layers and layer sizes. The hidden layers have ReLu activation. The output layer should not apply any activation function.

# %%
class MLP(nn.Module):

  def __init__(self,
               input_size,  # Size of the input. Here we will first flatten the image to a single vector with the 3 * 32 * 32 values in the image 
               layer_sizes,  # A tuple containing the sizes of the hidden layers of the neural network. So to create a NN with two hidden layers with 32 neurons in each layer you'd set layer_sizes=(32,32)
               output_size):  # The size of the network output. CIFAR10 has 10 output classes
    super(MLP, self).__init__()
    shape = (input_size,) + layer_sizes + (output_size,)
    self.layers = nn.ModuleList([nn.Linear(shape[i], shape[i+1]) for i in range(len(shape) - 1)])

    #pass  # COMPLETE THE CODE HERE

  def forward(self, x):
    for layer in self.layers[:-1]:
      x = F.relu(layer(x))
    return self.layers[-1](x)
    #pass  # COMPLETE THE CODE HERE

# %%
model = MLP(w * h * c, (128, 128), k).to(device)  # Create a new dense neural network with two hidden layers of size 128

print(model)
# Out:
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3072, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Train the network
#
# Finish the code below so the network is trained on the images. The network should be able to reach an accuracy of about 50%. This is much better than taking random guesses, so the network did learn something. However, it is not a great classifier either. Dense neural networks are usually not the way to go for image classification. Instead, Convolutional Neural Networks are often used. These will be covered in the next lecture.

# %%
start=time.time()

criterion = nn.CrossEntropyLoss()

lr = 0.01 # COMPLETE THE CODE HERE
momentum = 0.5 # COMPLETE THE CODE HERE
num_epochs = 20 # COMPLETE THE CODE HERE

optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

for epoch in range(1, num_epochs + 1):
  # Iterate through the entire train set
  for i, (x_batch, y_batch) in enumerate(trainloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used
    

    # Perform an optimization step on the network weights using the gradient of the loss function

    # COMPLETE THE CODE HERE
    optimizer.zero_grad()  # Set all currently stored gradients to zero 

    #x_batch = x_batch.view(-1, w*h*c)  # Reshape the input tensor
    #y_pred = model(x_batch)  # Perform the forward pass


    y_pred = model(x_batch.view(-1, w*h*c)) # COMPLETE THE CODE HERE

    loss = criterion(y_pred, y_batch) # COMPLETE THE CODE HERE

    # COMPLETE THE CODE HERE
    loss.backward()
    optimizer.step()

    # Compute relevant metrics
        
    y_pred_max = torch.argmax(y_pred, dim=1)  # Get the labels with highest output probability

    correct = torch.sum(torch.eq(y_pred_max, y_batch)).item()  # Count how many are equal to the true labels

    elapsed = time.time() - start  # Keep track of how much time has elapsed

    # Show progress every 20 batches 
    if not i % 20:
      print(f'epoch: {epoch}, time: {elapsed:.3f}s, loss: {loss.item():.3f}, train accuracy: {correct / batch_size:.3f}')
    
  # Evaluate the model on the test set
  correct_total = 0
  for i, (x_batch, y_batch) in enumerate(testloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used

    y_pred = model(x_batch.view(-1, w * h * c))
    y_pred_max = torch.argmax(y_pred, dim=1)

    correct_total += torch.sum(torch.eq(y_pred_max, y_batch)).item()

  print(f'Test accuracy: {correct_total / len(testset.data):.3f}')
# Out:
# epoch: 1, time: 0.030s, loss: 2.310, train accuracy: 0.078
# epoch: 1, time: 0.494s, loss: 2.228, train accuracy: 0.234
# epoch: 1, time: 0.932s, loss: 2.157, train accuracy: 0.250
# epoch: 1, time: 1.380s, loss: 2.128, train accuracy: 0.211
# epoch: 1, time: 1.811s, loss: 2.088, train accuracy: 0.227
# epoch: 1, time: 2.248s, loss: 2.017, train accuracy: 0.289
# epoch: 1, time: 2.673s, loss: 1.935, train accuracy: 0.281
# epoch: 1, time: 3.095s, loss: 1.973, train accuracy: 0.375
# epoch: 1, time: 3.537s, loss: 1.909, train accuracy: 0.297
# epoch: 1, time: 3.956s, loss: 1.870, train accuracy: 0.312
# epoch: 1, time: 4.386s, loss: 1.692, train accuracy: 0.453
# epoch: 1, time: 4.805s, loss: 1.814, train accuracy: 0.344
# epoch: 1, time: 5.248s, loss: 1.796, train accuracy: 0.344
# epoch: 1, time: 5.674s, loss: 1.744, train accuracy: 0.398
# epoch: 1, time: 6.089s, loss: 1.712, train accuracy: 0.438
# epoch: 1, time: 6.514s, loss: 1.853, train accuracy: 0.352
# epoch: 1, time: 6.934s, loss: 1.692, train accuracy: 0.406
# epoch: 1, time: 7.355s, loss: 1.788, train accuracy: 0.367
# epoch: 1, time: 7.776s, loss: 1.738, train accuracy: 0.367
# epoch: 1, time: 8.195s, loss: 1.695, train accuracy: 0.422
# Test accuracy: 0.401
# epoch: 2, time: 9.878s, loss: 1.601, train accuracy: 0.422
# epoch: 2, time: 10.297s, loss: 1.862, train accuracy: 0.328
# epoch: 2, time: 10.721s, loss: 1.621, train accuracy: 0.406
# epoch: 2, time: 11.142s, loss: 1.688, train accuracy: 0.375
# epoch: 2, time: 11.565s, loss: 1.928, train accuracy: 0.398
# epoch: 2, time: 11.986s, loss: 1.674, train accuracy: 0.398
# epoch: 2, time: 12.405s, loss: 1.630, train accuracy: 0.406
# epoch: 2, time: 12.823s, loss: 1.691, train accuracy: 0.375
# epoch: 2, time: 13.247s, loss: 1.532, train accuracy: 0.438
# epoch: 2, time: 13.668s, loss: 1.574, train accuracy: 0.484
# epoch: 2, time: 14.086s, loss: 1.735, train accuracy: 0.422
# epoch: 2, time: 14.505s, loss: 1.658, train accuracy: 0.422
# epoch: 2, time: 14.925s, loss: 1.633, train accuracy: 0.414
# epoch: 2, time: 15.349s, loss: 1.684, train accuracy: 0.469
# epoch: 2, time: 15.787s, loss: 1.642, train accuracy: 0.430
# epoch: 2, time: 16.209s, loss: 1.524, train accuracy: 0.430
# epoch: 2, time: 16.631s, loss: 1.532, train accuracy: 0.445
# epoch: 2, time: 17.057s, loss: 1.566, train accuracy: 0.492
# epoch: 2, time: 17.489s, loss: 1.695, train accuracy: 0.422
# epoch: 2, time: 17.926s, loss: 1.611, train accuracy: 0.422
# Test accuracy: 0.449
# epoch: 3, time: 19.766s, loss: 1.537, train accuracy: 0.484
# epoch: 3, time: 20.194s, loss: 1.482, train accuracy: 0.531
# epoch: 3, time: 20.665s, loss: 1.388, train accuracy: 0.578
# epoch: 3, time: 21.116s, loss: 1.549, train accuracy: 0.453
# epoch: 3, time: 21.584s, loss: 1.628, train accuracy: 0.484
# epoch: 3, time: 22.027s, loss: 1.448, train accuracy: 0.500
# epoch: 3, time: 22.466s, loss: 1.578, train accuracy: 0.438
# epoch: 3, time: 22.938s, loss: 1.535, train accuracy: 0.453
# epoch: 3, time: 23.376s, loss: 1.571, train accuracy: 0.445
# epoch: 3, time: 23.848s, loss: 1.608, train accuracy: 0.500
# epoch: 3, time: 24.288s, loss: 1.506, train accuracy: 0.414
# epoch: 3, time: 24.709s, loss: 1.628, train accuracy: 0.438
# epoch: 3, time: 25.132s, loss: 1.703, train accuracy: 0.414
# epoch: 3, time: 25.555s, loss: 1.430, train accuracy: 0.492
# epoch: 3, time: 25.976s, loss: 1.556, train accuracy: 0.453
# epoch: 3, time: 26.394s, loss: 1.549, train accuracy: 0.516
# epoch: 3, time: 26.813s, loss: 1.539, train accuracy: 0.438
# epoch: 3, time: 27.236s, loss: 1.539, train accuracy: 0.445
# epoch: 3, time: 27.654s, loss: 1.529, train accuracy: 0.484
# epoch: 3, time: 28.074s, loss: 1.533, train accuracy: 0.469
# Test accuracy: 0.467
# epoch: 4, time: 29.767s, loss: 1.581, train accuracy: 0.422
# epoch: 4, time: 30.202s, loss: 1.407, train accuracy: 0.508
# epoch: 4, time: 30.618s, loss: 1.636, train accuracy: 0.406
# epoch: 4, time: 31.038s, loss: 1.354, train accuracy: 0.469
# epoch: 4, time: 31.458s, loss: 1.323, train accuracy: 0.562
# epoch: 4, time: 31.884s, loss: 1.444, train accuracy: 0.508
# epoch: 4, time: 32.303s, loss: 1.477, train accuracy: 0.445
# epoch: 4, time: 32.735s, loss: 1.384, train accuracy: 0.547
# epoch: 4, time: 33.163s, loss: 1.402, train accuracy: 0.531
# epoch: 4, time: 33.591s, loss: 1.454, train accuracy: 0.477
# epoch: 4, time: 34.009s, loss: 1.423, train accuracy: 0.477
# epoch: 4, time: 34.431s, loss: 1.470, train accuracy: 0.453
# epoch: 4, time: 34.849s, loss: 1.518, train accuracy: 0.461
# epoch: 4, time: 35.265s, loss: 1.441, train accuracy: 0.484
# epoch: 4, time: 35.684s, loss: 1.533, train accuracy: 0.484
# epoch: 4, time: 36.102s, loss: 1.296, train accuracy: 0.570
# epoch: 4, time: 36.519s, loss: 1.439, train accuracy: 0.508
# epoch: 4, time: 36.936s, loss: 1.554, train accuracy: 0.445
# epoch: 4, time: 37.353s, loss: 1.510, train accuracy: 0.445
# epoch: 4, time: 37.776s, loss: 1.479, train accuracy: 0.445
# Test accuracy: 0.482
# epoch: 5, time: 39.444s, loss: 1.511, train accuracy: 0.438
# epoch: 5, time: 39.859s, loss: 1.358, train accuracy: 0.531
# epoch: 5, time: 40.276s, loss: 1.427, train accuracy: 0.430
# epoch: 5, time: 40.692s, loss: 1.488, train accuracy: 0.477
# epoch: 5, time: 41.113s, loss: 1.475, train accuracy: 0.461
# epoch: 5, time: 41.535s, loss: 1.398, train accuracy: 0.500
# epoch: 5, time: 41.952s, loss: 1.375, train accuracy: 0.492
# epoch: 5, time: 42.400s, loss: 1.473, train accuracy: 0.492
# epoch: 5, time: 42.818s, loss: 1.395, train accuracy: 0.539
# epoch: 5, time: 43.235s, loss: 1.382, train accuracy: 0.531
# epoch: 5, time: 43.652s, loss: 1.530, train accuracy: 0.508
# epoch: 5, time: 44.070s, loss: 1.412, train accuracy: 0.516
# epoch: 5, time: 44.486s, loss: 1.344, train accuracy: 0.508
# epoch: 5, time: 44.901s, loss: 1.436, train accuracy: 0.523
# epoch: 5, time: 45.326s, loss: 1.486, train accuracy: 0.555
# epoch: 5, time: 45.772s, loss: 1.468, train accuracy: 0.453
# epoch: 5, time: 46.193s, loss: 1.388, train accuracy: 0.523
# epoch: 5, time: 46.609s, loss: 1.237, train accuracy: 0.531
# epoch: 5, time: 47.026s, loss: 1.419, train accuracy: 0.523
# epoch: 5, time: 47.445s, loss: 1.306, train accuracy: 0.523
# Test accuracy: 0.498
# epoch: 6, time: 49.126s, loss: 1.237, train accuracy: 0.609
# epoch: 6, time: 49.544s, loss: 1.268, train accuracy: 0.578
# epoch: 6, time: 49.962s, loss: 1.469, train accuracy: 0.523
# epoch: 6, time: 50.384s, loss: 1.288, train accuracy: 0.547
# epoch: 6, time: 50.801s, loss: 1.465, train accuracy: 0.453
# epoch: 6, time: 51.224s, loss: 1.448, train accuracy: 0.500
# epoch: 6, time: 51.644s, loss: 1.405, train accuracy: 0.477
# epoch: 6, time: 52.065s, loss: 1.336, train accuracy: 0.555
# epoch: 6, time: 52.485s, loss: 1.444, train accuracy: 0.531
# epoch: 6, time: 52.909s, loss: 1.313, train accuracy: 0.516
# epoch: 6, time: 53.329s, loss: 1.271, train accuracy: 0.484
# epoch: 6, time: 53.751s, loss: 1.278, train accuracy: 0.594
# epoch: 6, time: 54.186s, loss: 1.515, train accuracy: 0.445
# epoch: 6, time: 54.605s, loss: 1.288, train accuracy: 0.609
# epoch: 6, time: 55.032s, loss: 1.455, train accuracy: 0.516
# epoch: 6, time: 55.448s, loss: 1.481, train accuracy: 0.438
# epoch: 6, time: 55.868s, loss: 1.131, train accuracy: 0.617
# epoch: 6, time: 56.286s, loss: 1.235, train accuracy: 0.555
# epoch: 6, time: 56.706s, loss: 1.418, train accuracy: 0.531
# epoch: 6, time: 57.123s, loss: 1.396, train accuracy: 0.500
# Test accuracy: 0.501
# epoch: 7, time: 58.805s, loss: 1.225, train accuracy: 0.570
# epoch: 7, time: 59.228s, loss: 1.447, train accuracy: 0.484
# epoch: 7, time: 59.649s, loss: 1.211, train accuracy: 0.578
# epoch: 7, time: 60.065s, loss: 1.387, train accuracy: 0.578
# epoch: 7, time: 60.485s, loss: 1.287, train accuracy: 0.570
# epoch: 7, time: 60.902s, loss: 1.164, train accuracy: 0.562
# epoch: 7, time: 61.323s, loss: 1.432, train accuracy: 0.477
# epoch: 7, time: 61.742s, loss: 1.277, train accuracy: 0.602
# epoch: 7, time: 62.162s, loss: 1.403, train accuracy: 0.453
# epoch: 7, time: 62.581s, loss: 1.456, train accuracy: 0.531
# epoch: 7, time: 62.999s, loss: 1.251, train accuracy: 0.617
# epoch: 7, time: 63.416s, loss: 1.471, train accuracy: 0.398
# epoch: 7, time: 63.831s, loss: 1.366, train accuracy: 0.492
# epoch: 7, time: 64.271s, loss: 1.187, train accuracy: 0.586
# epoch: 7, time: 64.695s, loss: 1.387, train accuracy: 0.492
# epoch: 7, time: 65.127s, loss: 1.289, train accuracy: 0.531
# epoch: 7, time: 65.607s, loss: 1.153, train accuracy: 0.617
# epoch: 7, time: 66.070s, loss: 1.248, train accuracy: 0.570
# epoch: 7, time: 66.510s, loss: 1.276, train accuracy: 0.469
# epoch: 7, time: 66.955s, loss: 1.436, train accuracy: 0.469
# Test accuracy: 0.506
# epoch: 8, time: 68.713s, loss: 1.397, train accuracy: 0.523
# epoch: 8, time: 69.186s, loss: 1.206, train accuracy: 0.570
# epoch: 8, time: 69.638s, loss: 1.363, train accuracy: 0.531
# epoch: 8, time: 70.088s, loss: 1.326, train accuracy: 0.539
# epoch: 8, time: 70.544s, loss: 1.326, train accuracy: 0.523
# epoch: 8, time: 70.987s, loss: 1.389, train accuracy: 0.477
# epoch: 8, time: 71.457s, loss: 1.248, train accuracy: 0.570
# epoch: 8, time: 71.894s, loss: 1.352, train accuracy: 0.484
# epoch: 8, time: 72.339s, loss: 1.359, train accuracy: 0.555
# epoch: 8, time: 72.801s, loss: 1.297, train accuracy: 0.531
# epoch: 8, time: 73.228s, loss: 1.328, train accuracy: 0.547
# epoch: 8, time: 73.685s, loss: 1.257, train accuracy: 0.555
# epoch: 8, time: 74.103s, loss: 1.225, train accuracy: 0.594
# epoch: 8, time: 74.562s, loss: 1.203, train accuracy: 0.609
# epoch: 8, time: 75.015s, loss: 1.426, train accuracy: 0.516
# epoch: 8, time: 75.476s, loss: 1.228, train accuracy: 0.578
# epoch: 8, time: 75.909s, loss: 1.391, train accuracy: 0.555
# epoch: 8, time: 76.350s, loss: 1.261, train accuracy: 0.555
# epoch: 8, time: 76.780s, loss: 1.124, train accuracy: 0.609
# epoch: 8, time: 77.206s, loss: 1.258, train accuracy: 0.555
# Test accuracy: 0.513
# epoch: 9, time: 78.953s, loss: 1.193, train accuracy: 0.570
# epoch: 9, time: 79.381s, loss: 1.272, train accuracy: 0.500
# epoch: 9, time: 79.894s, loss: 1.169, train accuracy: 0.562
# epoch: 9, time: 80.388s, loss: 1.222, train accuracy: 0.594
# epoch: 9, time: 80.825s, loss: 1.141, train accuracy: 0.602
# epoch: 9, time: 81.246s, loss: 1.214, train accuracy: 0.562
# epoch: 9, time: 81.670s, loss: 1.209, train accuracy: 0.570
# epoch: 9, time: 82.136s, loss: 1.205, train accuracy: 0.578
# epoch: 9, time: 82.561s, loss: 1.182, train accuracy: 0.602
# epoch: 9, time: 82.992s, loss: 1.286, train accuracy: 0.555
# epoch: 9, time: 83.484s, loss: 1.254, train accuracy: 0.547
# epoch: 9, time: 83.951s, loss: 1.130, train accuracy: 0.570
# epoch: 9, time: 84.413s, loss: 1.136, train accuracy: 0.617
# epoch: 9, time: 84.879s, loss: 1.099, train accuracy: 0.688
# epoch: 9, time: 85.406s, loss: 1.338, train accuracy: 0.539
# epoch: 9, time: 85.993s, loss: 1.209, train accuracy: 0.562
# epoch: 9, time: 86.485s, loss: 1.263, train accuracy: 0.508
# epoch: 9, time: 86.969s, loss: 1.310, train accuracy: 0.555
# epoch: 9, time: 87.456s, loss: 1.366, train accuracy: 0.523
# epoch: 9, time: 87.903s, loss: 1.367, train accuracy: 0.531
# Test accuracy: 0.516
# epoch: 10, time: 89.669s, loss: 1.152, train accuracy: 0.602
# epoch: 10, time: 90.091s, loss: 0.990, train accuracy: 0.695
# epoch: 10, time: 90.516s, loss: 1.264, train accuracy: 0.531
# epoch: 10, time: 90.949s, loss: 1.311, train accuracy: 0.508
# epoch: 10, time: 91.447s, loss: 1.301, train accuracy: 0.555
# epoch: 10, time: 91.883s, loss: 1.315, train accuracy: 0.523
# epoch: 10, time: 92.350s, loss: 1.143, train accuracy: 0.586
# epoch: 10, time: 92.849s, loss: 1.123, train accuracy: 0.555
# epoch: 10, time: 93.306s, loss: 1.269, train accuracy: 0.539
# epoch: 10, time: 93.781s, loss: 1.232, train accuracy: 0.602
# epoch: 10, time: 94.212s, loss: 1.188, train accuracy: 0.617
# epoch: 10, time: 94.668s, loss: 1.240, train accuracy: 0.547
# epoch: 10, time: 95.166s, loss: 1.158, train accuracy: 0.594
# epoch: 10, time: 95.599s, loss: 1.421, train accuracy: 0.484
# epoch: 10, time: 96.032s, loss: 1.179, train accuracy: 0.594
# epoch: 10, time: 96.471s, loss: 1.291, train accuracy: 0.562
# epoch: 10, time: 96.905s, loss: 1.190, train accuracy: 0.578
# epoch: 10, time: 97.326s, loss: 1.200, train accuracy: 0.578
# epoch: 10, time: 97.752s, loss: 1.345, train accuracy: 0.547
# epoch: 10, time: 98.189s, loss: 1.164, train accuracy: 0.609
# Test accuracy: 0.519
# epoch: 11, time: 99.905s, loss: 1.203, train accuracy: 0.578
# epoch: 11, time: 100.353s, loss: 1.070, train accuracy: 0.672
# epoch: 11, time: 100.819s, loss: 1.156, train accuracy: 0.586
# epoch: 11, time: 101.270s, loss: 1.244, train accuracy: 0.586
# epoch: 11, time: 101.717s, loss: 1.195, train accuracy: 0.617
# epoch: 11, time: 102.169s, loss: 1.273, train accuracy: 0.641
# epoch: 11, time: 102.612s, loss: 1.197, train accuracy: 0.602
# epoch: 11, time: 103.068s, loss: 1.348, train accuracy: 0.516
# epoch: 11, time: 103.493s, loss: 1.231, train accuracy: 0.625
# epoch: 11, time: 103.937s, loss: 1.174, train accuracy: 0.570
# epoch: 11, time: 104.358s, loss: 1.190, train accuracy: 0.609
# epoch: 11, time: 104.783s, loss: 1.099, train accuracy: 0.633
# epoch: 11, time: 105.202s, loss: 1.191, train accuracy: 0.586
# epoch: 11, time: 105.631s, loss: 1.146, train accuracy: 0.586
# epoch: 11, time: 106.051s, loss: 1.048, train accuracy: 0.641
# epoch: 11, time: 106.467s, loss: 1.149, train accuracy: 0.570
# epoch: 11, time: 106.884s, loss: 1.124, train accuracy: 0.586
# epoch: 11, time: 107.303s, loss: 1.281, train accuracy: 0.516
# epoch: 11, time: 107.722s, loss: 1.002, train accuracy: 0.648
# epoch: 11, time: 108.151s, loss: 1.118, train accuracy: 0.594
# Test accuracy: 0.513
# epoch: 12, time: 109.834s, loss: 1.206, train accuracy: 0.555
# epoch: 12, time: 110.251s, loss: 1.162, train accuracy: 0.578
# epoch: 12, time: 110.674s, loss: 1.229, train accuracy: 0.516
# epoch: 12, time: 111.124s, loss: 0.994, train accuracy: 0.664
# epoch: 12, time: 111.547s, loss: 1.002, train accuracy: 0.656
# epoch: 12, time: 111.969s, loss: 1.019, train accuracy: 0.641
# epoch: 12, time: 112.411s, loss: 1.199, train accuracy: 0.609
# epoch: 12, time: 112.860s, loss: 1.040, train accuracy: 0.664
# epoch: 12, time: 113.280s, loss: 1.246, train accuracy: 0.594
# epoch: 12, time: 113.714s, loss: 1.106, train accuracy: 0.648
# epoch: 12, time: 114.144s, loss: 1.083, train accuracy: 0.656
# epoch: 12, time: 114.566s, loss: 1.060, train accuracy: 0.617
# epoch: 12, time: 114.990s, loss: 1.106, train accuracy: 0.602
# epoch: 12, time: 115.423s, loss: 1.356, train accuracy: 0.516
# epoch: 12, time: 115.847s, loss: 1.096, train accuracy: 0.641
# epoch: 12, time: 116.266s, loss: 1.068, train accuracy: 0.625
# epoch: 12, time: 116.690s, loss: 1.073, train accuracy: 0.586
# epoch: 12, time: 117.121s, loss: 1.200, train accuracy: 0.594
# epoch: 12, time: 117.562s, loss: 1.151, train accuracy: 0.578
# epoch: 12, time: 117.992s, loss: 1.150, train accuracy: 0.633
# Test accuracy: 0.510
# epoch: 13, time: 119.673s, loss: 1.109, train accuracy: 0.609
# epoch: 13, time: 120.090s, loss: 1.052, train accuracy: 0.648
# epoch: 13, time: 120.517s, loss: 1.280, train accuracy: 0.586
# epoch: 13, time: 120.939s, loss: 1.252, train accuracy: 0.562
# epoch: 13, time: 121.363s, loss: 1.219, train accuracy: 0.625
# epoch: 13, time: 121.786s, loss: 1.119, train accuracy: 0.555
# epoch: 13, time: 122.206s, loss: 1.020, train accuracy: 0.609
# epoch: 13, time: 122.628s, loss: 0.849, train accuracy: 0.719
# epoch: 13, time: 123.053s, loss: 1.130, train accuracy: 0.602
# epoch: 13, time: 123.476s, loss: 1.088, train accuracy: 0.594
# epoch: 13, time: 123.913s, loss: 1.154, train accuracy: 0.586
# epoch: 13, time: 124.400s, loss: 1.297, train accuracy: 0.562
# epoch: 13, time: 124.822s, loss: 1.208, train accuracy: 0.617
# epoch: 13, time: 125.243s, loss: 1.209, train accuracy: 0.586
# epoch: 13, time: 125.664s, loss: 1.083, train accuracy: 0.594
# epoch: 13, time: 126.086s, loss: 1.133, train accuracy: 0.625
# epoch: 13, time: 126.513s, loss: 1.148, train accuracy: 0.594
# epoch: 13, time: 126.934s, loss: 1.085, train accuracy: 0.578
# epoch: 13, time: 127.355s, loss: 1.198, train accuracy: 0.617
# epoch: 13, time: 127.773s, loss: 1.182, train accuracy: 0.578
# Test accuracy: 0.522
# epoch: 14, time: 129.453s, loss: 0.941, train accuracy: 0.695
# epoch: 14, time: 129.877s, loss: 1.218, train accuracy: 0.578
# epoch: 14, time: 130.300s, loss: 1.136, train accuracy: 0.578
# epoch: 14, time: 130.725s, loss: 1.052, train accuracy: 0.641
# epoch: 14, time: 131.144s, loss: 0.987, train accuracy: 0.617
# epoch: 14, time: 131.567s, loss: 1.036, train accuracy: 0.648
# epoch: 14, time: 131.983s, loss: 1.131, train accuracy: 0.633
# epoch: 14, time: 132.402s, loss: 1.228, train accuracy: 0.602
# epoch: 14, time: 132.871s, loss: 1.036, train accuracy: 0.656
# epoch: 14, time: 133.357s, loss: 1.092, train accuracy: 0.602
# epoch: 14, time: 133.782s, loss: 1.077, train accuracy: 0.594
# epoch: 14, time: 134.222s, loss: 1.150, train accuracy: 0.633
# epoch: 14, time: 134.641s, loss: 1.212, train accuracy: 0.656
# epoch: 14, time: 135.072s, loss: 1.127, train accuracy: 0.562
# epoch: 14, time: 135.558s, loss: 1.193, train accuracy: 0.555
# epoch: 14, time: 136.024s, loss: 1.141, train accuracy: 0.617
# epoch: 14, time: 136.489s, loss: 0.983, train accuracy: 0.688
# epoch: 14, time: 136.933s, loss: 1.063, train accuracy: 0.617
# epoch: 14, time: 137.374s, loss: 1.141, train accuracy: 0.617
# epoch: 14, time: 137.826s, loss: 1.219, train accuracy: 0.617
# Test accuracy: 0.524
# epoch: 15, time: 139.596s, loss: 1.009, train accuracy: 0.664
# epoch: 15, time: 140.042s, loss: 1.086, train accuracy: 0.633
# epoch: 15, time: 140.471s, loss: 1.121, train accuracy: 0.625
# epoch: 15, time: 140.898s, loss: 1.197, train accuracy: 0.578
# epoch: 15, time: 141.322s, loss: 1.083, train accuracy: 0.602
# epoch: 15, time: 141.772s, loss: 1.117, train accuracy: 0.562
# epoch: 15, time: 142.191s, loss: 1.048, train accuracy: 0.672
# epoch: 15, time: 142.626s, loss: 1.298, train accuracy: 0.492
# epoch: 15, time: 143.045s, loss: 1.227, train accuracy: 0.578
# epoch: 15, time: 143.479s, loss: 1.311, train accuracy: 0.578
# epoch: 15, time: 143.905s, loss: 1.146, train accuracy: 0.625
# epoch: 15, time: 144.345s, loss: 1.091, train accuracy: 0.570
# epoch: 15, time: 144.779s, loss: 1.250, train accuracy: 0.570
# epoch: 15, time: 145.271s, loss: 0.921, train accuracy: 0.664
# epoch: 15, time: 145.778s, loss: 1.091, train accuracy: 0.664
# epoch: 15, time: 146.360s, loss: 1.070, train accuracy: 0.656
# epoch: 15, time: 146.850s, loss: 1.046, train accuracy: 0.594
# epoch: 15, time: 147.348s, loss: 1.034, train accuracy: 0.656
# epoch: 15, time: 147.816s, loss: 1.053, train accuracy: 0.641
# epoch: 15, time: 148.280s, loss: 1.082, train accuracy: 0.633
# Test accuracy: 0.526
# epoch: 16, time: 150.078s, loss: 1.002, train accuracy: 0.664
# epoch: 16, time: 150.546s, loss: 1.184, train accuracy: 0.578
# epoch: 16, time: 150.984s, loss: 1.141, train accuracy: 0.625
# epoch: 16, time: 151.421s, loss: 1.057, train accuracy: 0.656
# epoch: 16, time: 151.843s, loss: 1.140, train accuracy: 0.586
# epoch: 16, time: 152.260s, loss: 1.069, train accuracy: 0.594
# epoch: 16, time: 152.729s, loss: 0.932, train accuracy: 0.641
# epoch: 16, time: 153.173s, loss: 1.023, train accuracy: 0.633
# epoch: 16, time: 153.620s, loss: 0.903, train accuracy: 0.672
# epoch: 16, time: 154.092s, loss: 1.057, train accuracy: 0.617
# epoch: 16, time: 154.541s, loss: 1.001, train accuracy: 0.594
# epoch: 16, time: 154.966s, loss: 1.012, train accuracy: 0.648
# epoch: 16, time: 155.411s, loss: 1.031, train accuracy: 0.648
# epoch: 16, time: 155.833s, loss: 1.168, train accuracy: 0.617
# epoch: 16, time: 156.271s, loss: 1.121, train accuracy: 0.609
# epoch: 16, time: 156.718s, loss: 0.974, train accuracy: 0.656
# epoch: 16, time: 157.161s, loss: 1.161, train accuracy: 0.562
# epoch: 16, time: 157.651s, loss: 1.142, train accuracy: 0.664
# epoch: 16, time: 158.085s, loss: 1.098, train accuracy: 0.633
# epoch: 16, time: 158.524s, loss: 1.042, train accuracy: 0.633
# Test accuracy: 0.514
# epoch: 17, time: 160.353s, loss: 1.103, train accuracy: 0.641
# epoch: 17, time: 160.871s, loss: 1.047, train accuracy: 0.688
# epoch: 17, time: 161.330s, loss: 0.930, train accuracy: 0.602
# epoch: 17, time: 161.787s, loss: 1.118, train accuracy: 0.641
# epoch: 17, time: 162.240s, loss: 0.952, train accuracy: 0.633
# epoch: 17, time: 162.697s, loss: 1.023, train accuracy: 0.680
# epoch: 17, time: 163.126s, loss: 1.128, train accuracy: 0.570
# epoch: 17, time: 163.561s, loss: 1.159, train accuracy: 0.547
# epoch: 17, time: 163.984s, loss: 0.932, train accuracy: 0.703
# epoch: 17, time: 164.427s, loss: 0.975, train accuracy: 0.625
# epoch: 17, time: 164.861s, loss: 1.015, train accuracy: 0.625
# epoch: 17, time: 165.286s, loss: 1.081, train accuracy: 0.625
# epoch: 17, time: 165.733s, loss: 1.076, train accuracy: 0.648
# epoch: 17, time: 166.159s, loss: 0.981, train accuracy: 0.648
# epoch: 17, time: 166.592s, loss: 0.961, train accuracy: 0.664
# epoch: 17, time: 167.030s, loss: 0.964, train accuracy: 0.672
# epoch: 17, time: 167.466s, loss: 1.023, train accuracy: 0.625
# epoch: 17, time: 167.951s, loss: 1.001, train accuracy: 0.633
# epoch: 17, time: 168.390s, loss: 1.110, train accuracy: 0.625
# epoch: 17, time: 168.826s, loss: 1.149, train accuracy: 0.578
# Test accuracy: 0.520
# epoch: 18, time: 170.545s, loss: 1.016, train accuracy: 0.602
# epoch: 18, time: 170.979s, loss: 0.986, train accuracy: 0.656
# epoch: 18, time: 171.430s, loss: 0.997, train accuracy: 0.633
# epoch: 18, time: 171.914s, loss: 1.056, train accuracy: 0.625
# epoch: 18, time: 172.338s, loss: 1.108, train accuracy: 0.617
# epoch: 18, time: 172.768s, loss: 1.046, train accuracy: 0.586
# epoch: 18, time: 173.215s, loss: 0.835, train accuracy: 0.727
# epoch: 18, time: 173.652s, loss: 1.038, train accuracy: 0.609
# epoch: 18, time: 174.119s, loss: 0.841, train accuracy: 0.727
# epoch: 18, time: 174.561s, loss: 1.207, train accuracy: 0.539
# epoch: 18, time: 175.056s, loss: 1.034, train accuracy: 0.594
# epoch: 18, time: 175.501s, loss: 0.956, train accuracy: 0.680
# epoch: 18, time: 175.943s, loss: 1.007, train accuracy: 0.656
# epoch: 18, time: 176.438s, loss: 1.035, train accuracy: 0.625
# epoch: 18, time: 176.872s, loss: 1.071, train accuracy: 0.641
# epoch: 18, time: 177.328s, loss: 0.892, train accuracy: 0.703
# epoch: 18, time: 177.791s, loss: 0.855, train accuracy: 0.680
# epoch: 18, time: 178.210s, loss: 1.005, train accuracy: 0.688
# epoch: 18, time: 178.646s, loss: 0.996, train accuracy: 0.648
# epoch: 18, time: 179.082s, loss: 0.953, train accuracy: 0.664
# Test accuracy: 0.514
# epoch: 19, time: 180.796s, loss: 0.979, train accuracy: 0.664
# epoch: 19, time: 181.231s, loss: 0.942, train accuracy: 0.688
# epoch: 19, time: 181.652s, loss: 0.943, train accuracy: 0.633
# epoch: 19, time: 182.073s, loss: 1.080, train accuracy: 0.570
# epoch: 19, time: 182.490s, loss: 0.869, train accuracy: 0.664
# epoch: 19, time: 182.920s, loss: 1.063, train accuracy: 0.633
# epoch: 19, time: 183.346s, loss: 0.976, train accuracy: 0.656
# epoch: 19, time: 183.784s, loss: 1.036, train accuracy: 0.664
# epoch: 19, time: 184.223s, loss: 0.962, train accuracy: 0.680
# epoch: 19, time: 184.662s, loss: 0.800, train accuracy: 0.797
# epoch: 19, time: 185.087s, loss: 0.974, train accuracy: 0.695
# epoch: 19, time: 185.593s, loss: 1.186, train accuracy: 0.578
# epoch: 19, time: 186.108s, loss: 1.256, train accuracy: 0.531
# epoch: 19, time: 186.697s, loss: 1.121, train accuracy: 0.648
# epoch: 19, time: 187.165s, loss: 1.085, train accuracy: 0.570
# epoch: 19, time: 187.609s, loss: 0.937, train accuracy: 0.695
# epoch: 19, time: 188.082s, loss: 0.957, train accuracy: 0.664
# epoch: 19, time: 188.538s, loss: 0.939, train accuracy: 0.648
# epoch: 19, time: 188.985s, loss: 0.995, train accuracy: 0.602
# epoch: 19, time: 189.438s, loss: 1.214, train accuracy: 0.602
# Test accuracy: 0.522
# epoch: 20, time: 191.134s, loss: 0.877, train accuracy: 0.703
# epoch: 20, time: 191.565s, loss: 0.987, train accuracy: 0.680
# epoch: 20, time: 192.004s, loss: 1.050, train accuracy: 0.617
# epoch: 20, time: 192.456s, loss: 1.054, train accuracy: 0.602
# epoch: 20, time: 192.897s, loss: 0.967, train accuracy: 0.664
# epoch: 20, time: 193.335s, loss: 1.039, train accuracy: 0.641
# epoch: 20, time: 193.763s, loss: 0.717, train accuracy: 0.750
# epoch: 20, time: 194.221s, loss: 0.956, train accuracy: 0.695
# epoch: 20, time: 194.667s, loss: 1.037, train accuracy: 0.633
# epoch: 20, time: 195.123s, loss: 0.950, train accuracy: 0.664
# epoch: 20, time: 195.564s, loss: 1.049, train accuracy: 0.625
# epoch: 20, time: 196.019s, loss: 0.837, train accuracy: 0.734
# epoch: 20, time: 196.452s, loss: 0.944, train accuracy: 0.641
# epoch: 20, time: 196.892s, loss: 0.905, train accuracy: 0.703
# epoch: 20, time: 197.326s, loss: 0.867, train accuracy: 0.695
# epoch: 20, time: 197.779s, loss: 1.065, train accuracy: 0.609
# epoch: 20, time: 198.267s, loss: 1.021, train accuracy: 0.625
# epoch: 20, time: 198.731s, loss: 1.032, train accuracy: 0.602
# epoch: 20, time: 199.228s, loss: 0.967, train accuracy: 0.648
# epoch: 20, time: 199.690s, loss: 0.942, train accuracy: 0.641
# Test accuracy: 0.513

# %%
import os

folder_path = 'Densenet_on_cifarData/'

if not os.path.isdir(folder_path):
  os.mkdir(folder_path)
  print('Folder created!')

# %%
torch.save(model, folder_path + 'model.pth')

# %%
model = torch.load(folder_path + 'model.pth')
print(model)
# Out:
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3072, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
torch.save(model.state_dict(), folder_path + 'model_state.pth')

# %%
model_state = torch.load(folder_path + 'model_state.pth')  # Load the model's weights
model = MLP(w * h * c, (128, 128), k).to(device)  # Create a new dense neural network with two hidden layers of size 128
model.load_state_dict(model_state)  # Set the model weights to the saved weights. Note that the model architecture must be equal to the architecture of the model from which the state_dict was obtained!
# Out:
# <All keys matched successfully>
